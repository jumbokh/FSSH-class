# %%
import cv2
imagepath = "images/abba.png"
image = cv2.imread(imagepath)

# %% [markdown]
# ## 轉換成灰階圖片

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ## 載入人臉分類器

# %%
classifier = "haarcascades/haarcascade_frontalface_default.xml" #人脸分类器路径  #这里我用的haarcascade_frontalface_default.xml
face_cascade = cv2.CascadeClassifier(classifier)

# %% [markdown]
# ## 识别人脸

# %%
#探测图片中的人脸
#faces = face_cascade.detectMultiScale(image)
faces = face_cascade.detectMultiScale(gray)

# %%
print("发现{0}个人脸!".format(len(faces)))
# Out:
# 发现4个人脸!

# %% [markdown]
# ## 画图，圈中人脸

# %%
for(x,y,w,h) in faces:
   cv2.rectangle(image,(x,y),(x+w,y+w),(0,255,0),2)

# %% [markdown]
# ## 显示图像

# %%
cv2.imwrite('output/output.jpg', image)
# Out:
# True

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x426 at 0x7FBAD85B26D0>
